# %%
# !pip install seaborn scikit-learn kagglehub category_encoders

# %%
# df_scaled = pd.concat([df_scaled.loc[:, ~df_scaled.columns.isin(["Neighborhood","SalePrice"])],df_scaled["SalePrice"]],axis=1)

# df_scaled

# %%
# Standard libraries
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import norm, skew

# Sklearn: pipeline, preprocessing, model selection
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_validate, KFold, GridSearchCV

# Sklearn: regression models
from sklearn.linear_model import (
    LinearRegression, Ridge, Lasso, RidgeCV, ElasticNet, LogisticRegression
)
from sklearn.ensemble import (
    RandomForestRegressor, BaggingRegressor, GradientBoostingRegressor, AdaBoostRegressor,
    RandomForestClassifier, GradientBoostingClassifier
)
from sklearn.svm import SVR, LinearSVC, SVC
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB

# Sklearn: metrics
from sklearn.metrics import (
    mean_squared_log_error, mean_squared_error, r2_score, mean_absolute_error,
    accuracy_score, precision_score, recall_score, f1_score
)

# Custom modules (feature engineering & preprocessing)
from feature_engineering.feature_encoder import create_encoder_pipeline
from feature_engineering.feature_extraction import CorrelationSelector
from feature_engineering.feature_transformation import FeatureTransformer
from feature_engineering.feature_scaler import FeatureScaler
from preprocessor.imputer import Preprocessor

# Data ingestion
from data_injestion import train_df, test_df

# %%
ordinal_features = ["ExterQual", "BsmtQual", "KitchenQual","GarageFinish"]
ordinal_categories = [
    ["Po", "Fa", "TA", "Gd", "Ex"],        # ExterQual
    ["NA", "Po", "Fa", "TA", "Gd", "Ex"],  # BsmtQual
    ["Po", "Fa", "TA", "Gd", "Ex"],        # KitchenQual
    [ "NA", "Unf", "RFn", "Fin"]           # GarageFinish
]
high_cardinal_nominal_features = [ 'Neighborhood']
low_cardinal_nominal_features = ["Foundation"]

encoder = create_encoder_pipeline(ordinal_categories,ordinal_features,low_cardinal_nominal_features,high_cardinal_nominal_features,target="SalePrice")


def create_full_pipeline(target):
    full_pipeline = Pipeline([
        ("preprocessor",Preprocessor(cardinality_threshold=10, skew_threshold=0.5)),
        # ("visualize", CorrelationVisualizer(target="SalePrice")),
        ("selector",CorrelationSelector(target=target)),
        # ("num_selector", NumericCorrelationSelector(target_col="SalePrice", corr_threshold=0.7)),
        # ("cat_selector", CategoricalCorrelationSelector(target="SalePrice", eta_threshold=0.25, pvalue_threshold=0.05)),
        ("encoder",encoder),
        ("transformer", FeatureTransformer()),
        ("scaler", FeatureScaler(target=target))
        
    ])

    return full_pipeline

# %%
pipeline = create_full_pipeline(target="SalePrice")
pipeline.fit(train_df)
# Out:
# 🔄 Fitting DataPreprocessor on data with shape: (1460, 81)
# Step 1: Analyzing missing values...
# SUMMMARY
#                 ColumnName  MissingValues  MissingPercentage    Dtype  \
# PoolQC              PoolQC           1453              99.52   object
# MiscFeature    MiscFeature           1406              96.30   object
# Alley                Alley           1369              93.77   object
# Fence                Fence           1179              80.75   object
# MasVnrType      MasVnrType            872              59.73   object
# FireplaceQu    FireplaceQu            690              47.26   object
# LotFrontage    LotFrontage            259              17.74  float64
# GarageType      GarageType             81               5.55   object
# GarageYrBlt    GarageYrBlt             81               5.55  float64
# GarageFinish  GarageFinish             81               5.55   object
# GarageQual      GarageQual             81               5.55   object
# ...

# %%
train_df_final = pipeline.transform(train_df)
# Out:
# ✅ Successfully transformed to DataFrame: (1460, 77)
# [[3. 4. 3. 2.]
#  [2. 4. 2. 2.]
#  [3. 4. 3. 2.]
#  ...
#  [4. 3. 3. 2.]
#  [2. 3. 3. 1.]
#  [3. 3. 2. 3.]]
# Transformed data shape: (1460, 6)
# Feature names: ['Foundation_BrkTil' 'Foundation_CBlock' 'Foundation_PConc'
#  'Foundation_Slab' 'Foundation_Stone' 'Foundation_Wood']
# Number of feature names: 6

# %%
train_df_final
# Out:
#       OverallQual  GrLivArea  ExterQual  BsmtQual  KitchenQual  GarageFinish  \
# 0               7   0.529194          3         4            3             2
# 1               6  -0.381965          2         4            2             2
# 2               7   0.659631          3         4            3             2
# 3               7   0.541448          2         3            3             1
# 4               8   1.282295          3         4            3             2
# ...           ...        ...        ...       ...          ...           ...
# 1455            6   0.416598          2         4            2             2
# 1456            6   1.106648          2         4            2             1
# 1457            7   1.470102          4         3            3             2
# 1458            5  -0.854536          2         3            3             1
# 1459            5  -0.396257          3         3            2             3
#
# ...

# %%
df_train = pd.concat([train_df_final.loc[:, ~train_df_final.columns.isin(["Neighborhood","SalePrice"])],train_df_final["SalePrice"]],axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(df_train.drop(['SalePrice'],axis=1),df_train['SalePrice'],test_size=0.20,random_state=42)

# %%
reg_lin=LinearRegression()
reg_lin.fit(x_train,y_train)
pred=reg_lin.predict(x_test)
print(np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 0.1686824570445442

# %%
params_dict={'alpha':[0.001, 0.005, 0.01,0.05,0.1,0.5,1]}
reg_lasso_CV=GridSearchCV(estimator=Lasso(),param_grid=params_dict,scoring='neg_mean_squared_error',cv=10)
reg_lasso_CV.fit(x_train,y_train)
pred=reg_lasso_CV.predict(x_test)
print(np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 0.16832005823299878

# %%
retain_columns = pipeline.named_steps["selector"].selected_features_

# %%
def create_full_pipeline_test_data(target,sparse_columns):
    full_pipeline = Pipeline([
        ("preprocessor",Preprocessor(cardinality_threshold=10, skew_threshold=0.5,sparse_columns=["Id"],retain_columns=retain_columns)),
        # ("visualize", CorrelationVisualizer(target="SalePrice")),
        # ("selector",CorrelationSelector(target=target)),
        # ("num_selector", NumericCorrelationSelector(target_col="SalePrice", corr_threshold=0.7)),
        # ("cat_selector", CategoricalCorrelationSelector(target="SalePrice", eta_threshold=0.25, pvalue_threshold=0.05)),
        ("encoder",encoder),
        ("transformer", FeatureTransformer()),
        ("scaler", FeatureScaler(target=target))
        
    ])

    return full_pipeline

# %%
test_pipeline = create_full_pipeline_test_data("SalePrice",sparse_columns)

# %%
df_test = test_pipeline.fit_transform(test_df)
# Out:
# 🔄 Fitting DataPreprocessor on data with shape: (1459, 72)
# Step 1: Analyzing missing values...
# SUMMMARY
#                 ColumnName  MissingValues  MissingPercentage    Dtype  \
# PoolQC              PoolQC           1456              99.79   object
# MiscFeature    MiscFeature           1408              96.50   object
# Alley                Alley           1352              92.67   object
# Fence                Fence           1169              80.12   object
# MasVnrType      MasVnrType            894              61.27   object
# FireplaceQu    FireplaceQu            730              50.03   object
# LotFrontage    LotFrontage            227              15.56  float64
# GarageQual      GarageQual             78               5.35   object
# GarageYrBlt    GarageYrBlt             78               5.35  float64
# GarageCond      GarageCond             78               5.35   object
# GarageType      GarageType             76               5.21   object
# ...

# %%
test_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

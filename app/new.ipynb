# %%
from preprocessor.missing_value_analysis import MissingValueAnalyzer
from preprocessor.imputer import Preprocessor
from data_injestion import train_df,test_df
from preprocessor.main import DataPreprocessor
# missing_analyzer = MissingValueAnalyzer()
# sparse_columns,df = missing_analyzer(train_df)

# preprocessor = Preprocessor(skew_threshold=0.5, cardinality_threshold=10,sparse_columns=sparse_columns)
# df_clean = preprocessor.fit_transform(df)

# # print(cleaned_df.dtypes)
# print(df_clean[df.columns].head(5))
# print(df_clean.isnull().sum())

# print(train_df[df.columns].head(5))


# preprocessor = DataPreprocessor(cardinality_threshold=10, skew_threshold=0.5)
# preprocessor.fit(test_df)

# print(preprocessor.summary(test_df))

# df_imputed = preprocessor.transform(test_df)
df = test_df.copy()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
#  17  OverallQual    1459 non-null   int64
#  18  OverallCond    1459 non-null   int64
#  19  YearBuilt      1459 non-null   int64
#  20  YearRemodAdd   1459 non-null   int64
#  21  RoofStyle      1459 non-null   object
#  22  RoofMatl       1459 non-null   object
#  23  Exterior1st    1458 non-null   object
#  24  Exterior2nd    1458 non-null   object
#  25  MasVnrType     565 non-null    object
#  26  MasVnrArea     1444 non-null   float64
#  27  ExterQual      1459 non-null   object
#  28  ExterCond      1459 non-null   object
#  29  Foundation     1459 non-null   object
#  30  BsmtQual       1415 non-null   object
#  31  BsmtCond       1414 non-null   object
#  32  BsmtExposure   1415 non-null   object
#  33  BsmtFinType1   1417 non-null   object
#  34  BsmtFinSF1     1458 non-null   float64
#  35  BsmtFinType2   1417 non-null   object
#  36  BsmtFinSF2     1458 non-null   float64
#  37  BsmtUnfSF      1458 non-null   float64
#  38  TotalBsmtSF    1458 non-null   float64
#  39  Heating        1459 non-null   object
#  40  HeatingQC      1459 non-null   object
#  41  CentralAir     1459 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1459 non-null   int64
#  44  2ndFlrSF       1459 non-null   int64
#  45  LowQualFinSF   1459 non-null   int64
#  46  GrLivArea      1459 non-null   int64
#  47  BsmtFullBath   1457 non-null   float64
#  48  BsmtHalfBath   1457 non-null   float64
#  49  FullBath       1459 non-null   int64
#  50  HalfBath       1459 non-null   int64
#  51  BedroomAbvGr   1459 non-null   int64
#  52  KitchenAbvGr   1459 non-null   int64
#  53  KitchenQual    1458 non-null   object
#  54  TotRmsAbvGrd   1459 non-null   int64
#  55  Functional     1457 non-null   object
#  56  Fireplaces     1459 non-null   int64
#  57  FireplaceQu    729 non-null    object
#  58  GarageType     1383 non-null   object
#  59  GarageYrBlt    1381 non-null   float64
#  60  GarageFinish   1381 non-null   object
#  61  GarageCars     1458 non-null   float64
#  62  GarageArea     1458 non-null   float64
#  63  GarageQual     1381 non-null   object
#  64  GarageCond     1381 non-null   object
#  65  PavedDrive     1459 non-null   object
#  66  WoodDeckSF     1459 non-null   int64
#  67  OpenPorchSF    1459 non-null   int64
#  68  EnclosedPorch  1459 non-null   int64
#  69  3SsnPorch      1459 non-null   int64
#  70  ScreenPorch    1459 non-null   int64
#  71  PoolArea       1459 non-null   int64
#  72  PoolQC         3 non-null      object
#  73  Fence          290 non-null    object
#  74  MiscFeature    51 non-null     object
#  75  MiscVal        1459 non-null   int64
#  76  MoSold         1459 non-null   int64
#  77  YrSold         1459 non-null   int64
#  78  SaleType       1458 non-null   object
#  79  SaleCondition  1459 non-null   object
# dtypes: float64(11), int64(26), object(43)
# memory usage: 912.0+ KB

# %%
from preprocessor.missing_value_analysis import MissingValueAnalyzer
from data_injestion import train_df,test_df
from preprocessor.imputer import Preprocessor

sparse_columns = test_df.isnull().mean()[test_df.isnull().mean() > 0.8].index.to_list()
preprocessor = Preprocessor(cardinality_threshold=10, skew_threshold=0.5,sparse_columns=["Id"])
df_imputed = preprocessor.fit_transform(test_df)
df_imputed.head()
# Out:
# Data source import complete.
# 🔄 Fitting DataPreprocessor on data with shape: (1459, 79)
# Step 1: Analyzing missing values...
# SUMMMARY
#                 ColumnName  MissingValues  MissingPercentage    Dtype  \
# PoolQC              PoolQC           1456              99.79   object
# MiscFeature    MiscFeature           1408              96.50   object
# Alley                Alley           1352              92.67   object
# Fence                Fence           1169              80.12   object
# MasVnrType      MasVnrType            894              61.27   object
# FireplaceQu    FireplaceQu            730              50.03   object
# LotFrontage    LotFrontage            227              15.56  float64
# GarageQual      GarageQual             78               5.35   object
# GarageCond      GarageCond             78               5.35   object
# GarageYrBlt    GarageYrBlt             78               5.35  float64
# GarageFinish  GarageFinish             78               5.35   object
# GarageType      GarageType             76               5.21   object
# BsmtCond          BsmtCond             45               3.08   object
# BsmtQual          BsmtQual             44               3.02   object
# BsmtExposure  BsmtExposure             44               3.02   object
# BsmtFinType1  BsmtFinType1             42               2.88   object
# BsmtFinType2  BsmtFinType2             42               2.88   object
# MasVnrArea      MasVnrArea             15               1.03  float64
# MSZoning          MSZoning              4               0.27   object
# Functional      Functional              2               0.14   object
# BsmtFullBath  BsmtFullBath              2               0.14  float64
# Utilities        Utilities              2               0.14   object
# BsmtHalfBath  BsmtHalfBath              2               0.14  float64
# Exterior1st    Exterior1st              1               0.07   object
# Exterior2nd    Exterior2nd              1               0.07   object
# TotalBsmtSF    TotalBsmtSF              1               0.07  float64
# BsmtUnfSF        BsmtUnfSF              1               0.07  float64
# BsmtFinSF2      BsmtFinSF2              1               0.07  float64
# BsmtFinSF1      BsmtFinSF1              1               0.07  float64
# KitchenQual    KitchenQual              1               0.07   object
# GarageArea      GarageArea              1               0.07  float64
# GarageCars      GarageCars              1               0.07  float64
# SaleType          SaleType              1               0.07   object
#
#               UniqueValues     Strategy
# PoolQC                   2  Drop Column
# MiscFeature              3  Drop Column
# Alley                    2  Drop Column
# Fence                    4  Drop Column
# MasVnrType               3       Impute
# FireplaceQu              5       Impute
# LotFrontage            115       Impute
# GarageQual               4       Impute
# GarageCond               5       Impute
# GarageYrBlt             97       Impute
# GarageFinish             3       Impute
# GarageType               6       Impute
# BsmtCond                 4       Impute
# BsmtQual                 4       Impute
# BsmtExposure             4       Impute
# BsmtFinType1             6       Impute
# BsmtFinType2             6       Impute
# MasVnrArea             303       Impute
# MSZoning                 5       Impute
# Functional               7       Impute
# BsmtFullBath             4       Impute
# Utilities                1       Impute
# BsmtHalfBath             3       Impute
# Exterior1st             13       Impute
# Exterior2nd             15       Impute
# TotalBsmtSF            736       Impute
# BsmtUnfSF              793       Impute
# BsmtFinSF2             161       Impute
# BsmtFinSF1             669       Impute
# KitchenQual              4       Impute
# GarageArea             459       Impute
# GarageCars               6       Impute
# SaleType                 9       Impute
# Found 33 columns with missing values.
# Columns to drop (>80% missing): 5
# Step 2: Determining numeric imputation strategies...
# Step 3: Building preprocessing pipeline...
# Dropped 5 sparse columns
# Numeric columns: 36
# Low cardinality categorical: 36
# High cardinality categorical: 3
# Step 4: Fitting pipeline...
# ✅ DataPreprocessor fitted successfully!
# ✅ Successfully transformed to DataFrame: (1459, 75)
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          20         80.0    11622            5            6       1961
# 1          20         81.0    14267            6            6       1958
# 2          60         74.0    13830            5            5       1997
# 3          60         78.0     9978            6            6       1998
# 4         120         43.0     5005            8            5       1992
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          1961         0.0       468.0       144.0      270.0        882.0
# 1          1958       108.0       923.0         0.0      406.0       1329.0
# 2          1998         0.0       791.0         0.0      137.0        928.0
# 3          1998        20.0       602.0         0.0      324.0        926.0
# 4          1992         0.0       263.0         0.0     1017.0       1280.0
#
#    1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0       896         0             0        896           0.0           0.0
# 1      1329         0             0       1329           0.0           0.0
# 2       928       701             0       1629           0.0           0.0
# 3       926       678             0       1604           0.0           0.0
# 4      1280         0             0       1280           0.0           0.0
#
#    FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  \
# 0         1         0             2             1             5           0
# 1         1         1             3             1             6           0
# 2         2         1             3             1             6           1
# 3         2         1             3             1             7           1
# 4         2         0             2             1             5           0
#
#    GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  \
# 0       1961.0         1.0       730.0         140            0
# 1       1958.0         1.0       312.0         393           36
# 2       1997.0         2.0       482.0         212           34
# 3       1998.0         2.0       470.0         360           36
# 4       1992.0         2.0       506.0           0           82
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# 0              0          0          120         0        0       6    2010
# 1              0          0            0         0    12500       6    2010
# 2              0          0            0         0        0       3    2010
# 3              0          0            0         0        0       6    2010
# 4              0          0          144         0        0       1    2010
#
#   MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RH   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 2       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 4       RL   Pave      IR1         HLS    AllPub    Inside       Gtl
#
#   Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl MasVnrType  \
# 0      Feedr       Norm     1Fam     1Story     Gable  CompShg    BrkFace
# 1       Norm       Norm     1Fam     1Story       Hip  CompShg    BrkFace
# 2       Norm       Norm     1Fam     2Story     Gable  CompShg    BrkFace
# 3       Norm       Norm     1Fam     2Story     Gable  CompShg    BrkFace
# 4       Norm       Norm   TwnhsE     1Story     Gable  CompShg    BrkFace
#
#   ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0        TA        TA     CBlock       TA       TA           No          Rec
# 1        TA        TA     CBlock       TA       TA           No          ALQ
# 2        TA        TA      PConc       Gd       TA           No          GLQ
# 3        TA        TA      PConc       TA       TA           No          GLQ
# 4        Gd        TA      PConc       Gd       TA           No          ALQ
#
#   BsmtFinType2 Heating HeatingQC CentralAir Electrical KitchenQual Functional  \
# 0          LwQ    GasA        TA          Y      SBrkr          TA        Typ
# 1          Unf    GasA        TA          Y      SBrkr          Gd        Typ
# 2          Unf    GasA        Gd          Y      SBrkr          TA        Typ
# 3          Unf    GasA        Ex          Y      SBrkr          Gd        Typ
# 4          Unf    GasA        Ex          Y      SBrkr          Gd        Typ
#
#   FireplaceQu GarageType GarageFinish GarageQual GarageCond PavedDrive  \
# 0          Gd     Attchd          Unf         TA         TA          Y
# 1          Gd     Attchd          Unf         TA         TA          Y
# 2          TA     Attchd          Fin         TA         TA          Y
# 3          Gd     Attchd          Fin         TA         TA          Y
# 4          Gd     Attchd          RFn         TA         TA          Y
#
#   SaleType SaleCondition Neighborhood Exterior1st Exterior2nd
# 0       WD        Normal        NAmes     VinylSd     VinylSd
# 1       WD        Normal        NAmes     Wd Sdng     Wd Sdng
# 2       WD        Normal      Gilbert     VinylSd     VinylSd
# 3       WD        Normal      Gilbert     VinylSd     VinylSd
# 4       WD        Normal      StoneBr     HdBoard     HdBoard

# %%
im_df = df_imputed.isnull().sum().to_frame("Count")
im_df.query("Count > 0").empty
# Out:
# True

# %%
df.loc[:,df_imputed.columns]
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             20         80.0    11622            5            6       1961
# 1             20         81.0    14267            6            6       1958
# 2             60         74.0    13830            5            5       1997
# 3             60         78.0     9978            6            6       1998
# 4            120         43.0     5005            8            5       1992
# ...          ...          ...      ...          ...          ...        ...
# 1454         160         21.0     1936            4            7       1970
# 1455         160         21.0     1894            4            5       1970
# 1456          20        160.0    20000            5            7       1960
# 1457          85         62.0    10441            5            5       1992
# 1458          60         74.0     9627            7            5       1993
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0             1961         0.0       468.0       144.0      270.0
# 1             1958       108.0       923.0         0.0      406.0
# 2             1998         0.0       791.0         0.0      137.0
# 3             1998        20.0       602.0         0.0      324.0
# 4             1992         0.0       263.0         0.0     1017.0
# ...            ...         ...         ...         ...        ...
# 1454          1970         0.0         0.0         0.0      546.0
# 1455          1970         0.0       252.0         0.0      294.0
# 1456          1996         0.0      1224.0         0.0        0.0
# 1457          1992         0.0       337.0         0.0      575.0
# 1458          1994        94.0       758.0         0.0      238.0
#
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 0           882.0       896         0             0        896           0.0
# 1          1329.0      1329         0             0       1329           0.0
# 2           928.0       928       701             0       1629           0.0
# 3           926.0       926       678             0       1604           0.0
# 4          1280.0      1280         0             0       1280           0.0
# ...           ...       ...       ...           ...        ...           ...
# 1454        546.0       546       546             0       1092           0.0
# 1455        546.0       546       546             0       1092           0.0
# 1456       1224.0      1224         0             0       1224           1.0
# 1457        912.0       970         0             0        970           0.0
# 1458        996.0       996      1004             0       2000           0.0
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0              0.0         1         0             2             1
# 1              0.0         1         1             3             1
# 2              0.0         2         1             3             1
# 3              0.0         2         1             3             1
# 4              0.0         2         0             2             1
# ...            ...       ...       ...           ...           ...
# 1454           0.0         1         1             3             1
# 1455           0.0         1         1             3             1
# 1456           0.0         1         0             4             1
# 1457           1.0         1         0             3             1
# 1458           0.0         2         1             3             1
#
#       TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  GarageArea  \
# 0                5           0       1961.0         1.0       730.0
# 1                6           0       1958.0         1.0       312.0
# 2                6           1       1997.0         2.0       482.0
# 3                7           1       1998.0         2.0       470.0
# 4                5           0       1992.0         2.0       506.0
# ...            ...         ...          ...         ...         ...
# 1454             5           0          NaN         0.0         0.0
# 1455             6           0       1970.0         1.0       286.0
# 1456             7           1       1960.0         2.0       576.0
# 1457             6           0          NaN         0.0         0.0
# 1458             9           1       1993.0         3.0       650.0
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0            140            0              0          0          120
# 1            393           36              0          0            0
# 2            212           34              0          0            0
# 3            360           36              0          0            0
# 4              0           82              0          0          144
# ...          ...          ...            ...        ...          ...
# 1454           0            0              0          0            0
# 1455           0           24              0          0            0
# 1456         474            0              0          0            0
# 1457          80           32              0          0            0
# 1458         190           48              0          0            0
#
#       PoolArea  MiscVal  MoSold  YrSold MSZoning Street LotShape LandContour  \
# 0            0        0       6    2010       RH   Pave      Reg         Lvl
# 1            0    12500       6    2010       RL   Pave      IR1         Lvl
# 2            0        0       3    2010       RL   Pave      IR1         Lvl
# 3            0        0       6    2010       RL   Pave      IR1         Lvl
# 4            0        0       1    2010       RL   Pave      IR1         HLS
# ...        ...      ...     ...     ...      ...    ...      ...         ...
# 1454         0        0       6    2006       RM   Pave      Reg         Lvl
# 1455         0        0       4    2006       RM   Pave      Reg         Lvl
# 1456         0        0       9    2006       RL   Pave      Reg         Lvl
# 1457         0      700       7    2006       RL   Pave      Reg         Lvl
# 1458         0        0      11    2006       RL   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope Condition1 Condition2 BldgType HouseStyle  \
# 0       AllPub    Inside       Gtl      Feedr       Norm     1Fam     1Story
# 1       AllPub    Corner       Gtl       Norm       Norm     1Fam     1Story
# 2       AllPub    Inside       Gtl       Norm       Norm     1Fam     2Story
# 3       AllPub    Inside       Gtl       Norm       Norm     1Fam     2Story
# 4       AllPub    Inside       Gtl       Norm       Norm   TwnhsE     1Story
# ...        ...       ...       ...        ...        ...      ...        ...
# 1454    AllPub    Inside       Gtl       Norm       Norm    Twnhs     2Story
# 1455    AllPub    Inside       Gtl       Norm       Norm   TwnhsE     2Story
# 1456    AllPub    Inside       Gtl       Norm       Norm     1Fam     1Story
# 1457    AllPub    Inside       Gtl       Norm       Norm     1Fam     SFoyer
# 1458    AllPub    Inside       Mod       Norm       Norm     1Fam     2Story
#
#      RoofStyle RoofMatl MasVnrType ExterQual ExterCond Foundation BsmtQual  \
# 0        Gable  CompShg        NaN        TA        TA     CBlock       TA
# 1          Hip  CompShg    BrkFace        TA        TA     CBlock       TA
# 2        Gable  CompShg        NaN        TA        TA      PConc       Gd
# 3        Gable  CompShg    BrkFace        TA        TA      PConc       TA
# 4        Gable  CompShg        NaN        Gd        TA      PConc       Gd
# ...        ...      ...        ...       ...       ...        ...      ...
# 1454     Gable  CompShg        NaN        TA        TA     CBlock       TA
# 1455     Gable  CompShg        NaN        TA        TA     CBlock       TA
# 1456     Gable  CompShg        NaN        TA        TA     CBlock       TA
# 1457     Gable  CompShg        NaN        TA        TA      PConc       Gd
# 1458     Gable  CompShg    BrkFace        TA        TA      PConc       Gd
#
#      BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2 Heating HeatingQC  \
# 0          TA           No          Rec          LwQ    GasA        TA
# 1          TA           No          ALQ          Unf    GasA        TA
# 2          TA           No          GLQ          Unf    GasA        Gd
# 3          TA           No          GLQ          Unf    GasA        Ex
# 4          TA           No          ALQ          Unf    GasA        Ex
# ...       ...          ...          ...          ...     ...       ...
# 1454       TA           No          Unf          Unf    GasA        Gd
# 1455       TA           No          Rec          Unf    GasA        TA
# 1456       TA           No          ALQ          Unf    GasA        Ex
# 1457       TA           Av          GLQ          Unf    GasA        TA
# 1458       TA           Av          LwQ          Unf    GasA        Ex
#
#      CentralAir Electrical KitchenQual Functional FireplaceQu GarageType  \
# 0             Y      SBrkr          TA        Typ         NaN     Attchd
# 1             Y      SBrkr          Gd        Typ         NaN     Attchd
# 2             Y      SBrkr          TA        Typ          TA     Attchd
# 3             Y      SBrkr          Gd        Typ          Gd     Attchd
# 4             Y      SBrkr          Gd        Typ         NaN     Attchd
# ...         ...        ...         ...        ...         ...        ...
# 1454          Y      SBrkr          TA        Typ         NaN        NaN
# 1455          Y      SBrkr          TA        Typ         NaN    CarPort
# 1456          Y      SBrkr          TA        Typ          TA     Detchd
# 1457          Y      SBrkr          TA        Typ         NaN        NaN
# 1458          Y      SBrkr          TA        Typ          TA     Attchd
#
#      GarageFinish GarageQual GarageCond PavedDrive SaleType SaleCondition  \
# 0             Unf         TA         TA          Y       WD        Normal
# 1             Unf         TA         TA          Y       WD        Normal
# 2             Fin         TA         TA          Y       WD        Normal
# 3             Fin         TA         TA          Y       WD        Normal
# 4             RFn         TA         TA          Y       WD        Normal
# ...           ...        ...        ...        ...      ...           ...
# 1454          NaN        NaN        NaN          Y       WD        Normal
# 1455          Unf         TA         TA          Y       WD       Abnorml
# 1456          Unf         TA         TA          Y       WD       Abnorml
# 1457          NaN        NaN        NaN          Y       WD        Normal
# 1458          Fin         TA         TA          Y       WD        Normal
#
#      Neighborhood Exterior1st Exterior2nd
# 0           NAmes     VinylSd     VinylSd
# 1           NAmes     Wd Sdng     Wd Sdng
# 2         Gilbert     VinylSd     VinylSd
# 3         Gilbert     VinylSd     VinylSd
# 4         StoneBr     HdBoard     HdBoard
# ...           ...         ...         ...
# 1454      MeadowV     CemntBd     CmentBd
# 1455      MeadowV     CemntBd     CmentBd
# 1456      Mitchel     VinylSd     VinylSd
# 1457      Mitchel     HdBoard     Wd Shng
# 1458      Mitchel     HdBoard     HdBoard
#
# [1459 rows x 75 columns]

# %%
df_imputed = df_imputed.astype(df.loc[:,df_imputed.columns].dtypes.to_dict())
